# %%
# You can run this block to set up your environment. You don't need to run this block if you have already
# finished your environment set up
# !pip install nltk
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install tensorflow
# Out:
# Requirement already satisfied: nltk in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: click in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (8.6.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# ## Data Loader

# %% [markdown]
# Python provides a lot of packages to load files in different formats. We provide a simple data loader to help you load .csv files.

# %%
import pandas as pd

def load_data(file_name):
    """
    :param file_name: a file name, type: str
    return a list of ids, a list of reviews, a list of labels
    https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
    """
    df = pd.read_csv(file_name)

    return df['id'], df["text"], df['label']

def load_labels(file_name):
    """
    :param file_name: a file name, type: str
    return a list of labels
    """
    return pd.read_csv(file_name)['label']

def write_predictions(file_name, pred):
    df = pd.DataFrame(zip(range(len(pred)), pred))
    df.columns = ["id", "label"]
    df.to_csv(file_name, index=False)

# %% [markdown]
# ## Feature Extractor

# %% [markdown]
# The **feature extractor** is one of the most important parts in a pipeline.
# In this tutorial, we introduce four different functions to extract features.

# %%
import nltk

def tokenize(text):
    """
    :param text: a doc with multiple sentences, type: str
    return a word list, type: list
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    """
    return nltk.word_tokenize(text)

# %% [markdown]
# Given a sentence. *'Text mining is to identify useful information.'*, this function is used to tokenize it to a list of tokens.

# %%
tokens = tokenize("Text mining is to identify useful information.")
print(tokens)
# Out:
# ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']

# %% [markdown]
# Here we simply treat each word as a feature. Assume we get all features, the next step is to make these features suitable for the following models.
# One simple and common way is to use the one-hot vector (maybe it is not the best solution).

# %%
import numpy as np

def get_onehot_vector(feats, feats_dict):
    """
    :param data: a list of features, type: list
    :param feats_dict: a dict from features to indices, type: dict
    return a feature vector,
    """
    # initialize the vector as all zeros
    vector = np.zeros(len(feats_dict), dtype=float)
    for f in feats:
        # get the feature index, return -1 if the feature is not existed
        f_idx = feats_dict.get(f, -1)
        if f_idx != -1:
            # set the corresponding element as 1
            vector[f_idx] = 1
    return vector

# %%
print(get_onehot_vector(tokens, {"Text": 0, "mining": 1, "COMP": 2, "HKUST": 3}))
# Out:
# [1. 1. 0. 0.]

# %% [markdown]
# In this example, "text" and "mine" appears in the tokens but "COMP" and "HKUST" not. So the 0 th, 1 th elements are ones and other elements are ones.

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Single Layer Perceptron

# %% [markdown]
# We introduce a 1-layer perceptron to classify reviews. This perceptron includes 1 dense layer with the softmax activation.
# Keras is the easiest deep learning framework so that we choose it to build this network.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
import tensorflow.keras as K


def build_SLP(input_size, output_size, learning_rate=0.1, l2_reg=0.0):
    """
    :param input_size: the dimension of the input, type: int
    :param output_size: the dimension of the prediction, type: int
    :param learning_rate: the learning rate for SGD
    :param l2_reg: the weight for the L2 regularizer
    return a 1-layer perceptron,
    """
    model = Sequential()
    
    # add 1 layer with softmax activation
    # you should specify the output size, the input_size, and the activation function
    model.add(Dense(output_size, activation="softmax", input_dim=input_size,
                kernel_initializer=K.initializers.he_normal(seed=0),
                bias_initializer="zeros",
                kernel_regularizer=K.regularizers.l2(l2_reg)))
    
    # set the loss as categorical_crossentropy, the metric as accuracy, and the optimizer as SGD
    model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=learning_rate), metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Multi Layer Perceptron

# %% [markdown]
# One vital change in multi-layer perceptron is the number of layers. We stack more layers so that extracted features can be further enhanced in hidden layers.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization, LayerNormalization

def build_MLP(input_size, output_size, num_layers, hidden_size,
              activation="relu",
              dropout_rate=0.0,
              batch_norm=False,
              layer_norm=False,
              l2_reg=0.0,
              loss="categorical_crossentropy",
              optimizer="SGD",
              learning_rate=0.1,
              metric="accuracy"):
    """
    :param input_size: the dimension of the input, type: int
    :param output_size: the dimension of the prediction, type: int
    :param num_layers: the number of layers, type: int
    :param hidden_size: the dimension of the hidden states, type: int
    :param activation: the activation type, type: str
    :param dropout_rate: the probability of dropout, type: float
    :param batch_norm: whether to enable batch normalization, type: bool
    :param layer_norm: whether to enable layer normalization, type: bool
    :param l2_reg: the weight for the L2 regularizer, type: float
    :param loss: the training loss, type: str
    :param optimizer: the optimizer, type: str
    :param learning_rate: the learning rate for the optimizer, type: float
    :param metric: the metric, type: str
    return: a multi-layer perceptron
    """
    model = Sequential()

    if num_layers == 1:
        model.add(Dense(output_size,
                        activation="softmax",
                        input_dim=input_size,
                        kernel_initializer=K.initializers.he_normal(seed=0),
                        bias_initializer="zeros",
                        kernel_regularizer=K.regularizers.l2(l2_reg)))
    else:
        for i in range(num_layers - 1):
            if i == 0:
                # first layer: input -> hidden
                model.add(Dense(hidden_size,
                                input_dim=input_size,
                                kernel_initializer=K.initializers.he_normal(seed=0),
                                bias_initializer="zeros",
                                kernel_regularizer=K.regularizers.l2(l2_reg)))
            else:
                # hidden layers: hidden -> hidden
                model.add(Dense(hidden_size,
                                kernel_initializer=K.initializers.he_normal(seed=0),
                                bias_initializer="zeros",
                                kernel_regularizer=K.regularizers.l2(l2_reg)))

            # add layer_norm
            if layer_norm:
                model.add(LayerNormalization())
            # add batch_norm
            if batch_norm:
                model.add(BatchNormalization())
            # add activation
            model.add(Activation(activation))
            # add dropout here (set seed as 0 in order to reproduce)
            if dropout_rate > 0.0:
                model.add(Dropout(dropout_rate, seed=0))

        # last layer: hidden -> class
        model.add(Dense(output_size,
                        activation="softmax",
                        kernel_initializer=K.initializers.he_normal(seed=0),
                        bias_initializer="zeros"))

    # set the loss, the optimizer, and the metric
    if optimizer == "SGD":
        optimizer = K.optimizers.SGD(learning_rate=learning_rate)
    elif optimizer == "RMSprop":
        optimizer = K.optimizers.RMSprop(learning_rate=learning_rate)
    elif optimizer == "Adam":
        optimizer = K.optimizers.Adam(learning_rate=learning_rate)
    else:
        raise NotImplementedError("Optimizer not implemented.")
    
    model.compile(loss=loss, optimizer=optimizer, metrics=[metric])
    
    return model

# %% [markdown]
# ### Connect All Parts

# %% [markdown]
# Now we have the data loader, feature extractor, and the classifier. We can connect them to finish this pipeline of classification.

# %%
train_file = "data/train.csv"
test_file = "data/test.csv"
ans_file = "data/ans.csv"
pred_file = "data/pred.csv"

# load data
train_ids, train_texts, train_labels = load_data(train_file)
test_ids, test_texts, _ = load_data(test_file)
test_labels = load_labels(ans_file)

# extract features

# tokenization
# the input is the text and the output is the word list
train_tokens = [tokenize(text) for text in train_texts]
test_tokens = [tokenize(text) for text in test_texts]


# build the feature list
train_feats = list()
for i in range(len(train_ids)):
    # concatenate the stemmed token list and the 2_gram list together
    train_feats.append(train_tokens[i])
test_feats = list()
for i in range(len(test_ids)):
    # concatenate the stemmed token list and the 2_gram list together
    test_feats.append(test_tokens[i])

# build the feature dict
feats = set()
# collect all features
for f in train_feats:
    feats.update(f)
print("Size of features:", len(feats))
# build a mapping from features to indices
feats_dict = dict(zip(feats, range(len(feats))))

# build the feats_matrix
# convert each example to a ont-hot vector, and then stack vectors as a matrix
train_feats_matrix = np.vstack([get_onehot_vector(f, feats_dict) for f in train_feats])
test_feats_matrix = np.vstack([get_onehot_vector(f, feats_dict) for f in test_feats])

# convert labels to label_matrix
num_classes = max(train_labels)
# convert each label to a ont-hot vector, and then stack vectors as a matrix
train_label_matrix = tf.keras.utils.to_categorical(train_labels-1, num_classes=num_classes)
test_label_matrix = tf.keras.utils.to_categorical(test_labels-1, num_classes=num_classes)
# Out:
# Size of features: 16202

# %%
# build the classifier

model_SLP = build_SLP(len(feats_dict), num_classes, learning_rate=0.1)

model_MLP = build_MLP(len(feats_dict), num_classes, 3, 1024, learning_rate=0.1)
# Out:
# /home/qzong/anaconda3/envs/COMP4332/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Splite Validation Set and Train the model

# %% [markdown]
# When we do not know the test performance, it is not easy to check when the classifier is good enough. Hence, we set the epochs manually (e.g. total_epoch = 10).
# If we have a validation set, we can use the validation performance to find the best classifier during the training.

# %%
print(train_feats_matrix.shape, train_label_matrix.shape)
# Out:
# (2000, 16202) (2000, 5)

# %%
from sklearn.model_selection import train_test_split
train_feats_matrix, val_feats_matrix, train_label_matrix, val_label_matrix = train_test_split(
    train_feats_matrix, train_label_matrix, test_size=0.1, random_state=42
)

# training
history_SLP = model_SLP.fit(train_feats_matrix, train_label_matrix,
                    validation_data=(val_feats_matrix, val_label_matrix),
                    epochs=50, batch_size=100)

history_MLP = model_MLP.fit(train_feats_matrix, train_label_matrix,
                    validation_data=(val_feats_matrix, val_label_matrix),
                    epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3910 - loss: 1.4703 - val_accuracy: 0.4750 - val_loss: 1.3428
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4816 - loss: 1.2642 - val_accuracy: 0.4950 - val_loss: 1.2661
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5327 - loss: 1.1584 - val_accuracy: 0.5200 - val_loss: 1.2168
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5734 - loss: 1.0834 - val_accuracy: 0.5200 - val_loss: 1.1813
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6083 - loss: 1.0252 - val_accuracy: 0.5250 - val_loss: 1.1541
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6326 - loss: 0.9774 - val_accuracy: 0.5300 - val_loss: 1.1324
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6586 - loss: 0.9368 - val_accuracy: 0.5400 - val_loss: 1.1144
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6759 - loss: 0.9014 - val_accuracy: 0.5550 - val_loss: 1.0992
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6960 - loss: 0.8699 - val_accuracy: 0.5800 - val_loss: 1.0862
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7128 - loss: 0.8417 - val_accuracy: 0.5850 - val_loss: 1.0748
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7251 - loss: 0.8160 - val_accuracy: 0.5950 - val_loss: 1.0649
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7341 - loss: 0.7924 - val_accuracy: 0.5950 - val_loss: 1.0560
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7458 - loss: 0.7706 - val_accuracy: 0.5900 - val_loss: 1.0481
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7547 - loss: 0.7505 - val_accuracy: 0.5950 - val_loss: 1.0411
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7602 - loss: 0.7316 - val_accuracy: 0.6050 - val_loss: 1.0347
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7684 - loss: 0.7140 - val_accuracy: 0.6050 - val_loss: 1.0289
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7771 - loss: 0.6974 - val_accuracy: 0.6050 - val_loss: 1.0236
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7825 - loss: 0.6817 - val_accuracy: 0.6050 - val_loss: 1.0188
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7869 - loss: 0.6669 - val_accuracy: 0.6050 - val_loss: 1.0144
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8015 - loss: 0.6528 - val_accuracy: 0.6050 - val_loss: 1.0103
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8054 - loss: 0.6395 - val_accuracy: 0.6100 - val_loss: 1.0066
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8072 - loss: 0.6268 - val_accuracy: 0.6100 - val_loss: 1.0032
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8113 - loss: 0.6147 - val_accuracy: 0.6100 - val_loss: 1.0000
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8148 - loss: 0.6031 - val_accuracy: 0.6250 - val_loss: 0.9970
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8258 - loss: 0.5920 - val_accuracy: 0.6300 - val_loss: 0.9943
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8296 - loss: 0.5813 - val_accuracy: 0.6350 - val_loss: 0.9918
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8343 - loss: 0.5711 - val_accuracy: 0.6350 - val_loss: 0.9894
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8401 - loss: 0.5613 - val_accuracy: 0.6300 - val_loss: 0.9872
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8469 - loss: 0.5519 - val_accuracy: 0.6250 - val_loss: 0.9851
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8548 - loss: 0.5428 - val_accuracy: 0.6250 - val_loss: 0.9832
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8581 - loss: 0.5340 - val_accuracy: 0.6250 - val_loss: 0.9814
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8638 - loss: 0.5256 - val_accuracy: 0.6250 - val_loss: 0.9797
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8673 - loss: 0.5174 - val_accuracy: 0.6250 - val_loss: 0.9782
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8709 - loss: 0.5095 - val_accuracy: 0.6250 - val_loss: 0.9767
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8752 - loss: 0.5019 - val_accuracy: 0.6250 - val_loss: 0.9753
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8781 - loss: 0.4945 - val_accuracy: 0.6250 - val_loss: 0.9740
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8806 - loss: 0.4874 - val_accuracy: 0.6250 - val_loss: 0.9728
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8820 - loss: 0.4804 - val_accuracy: 0.6250 - val_loss: 0.9717
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8864 - loss: 0.4737 - val_accuracy: 0.6300 - val_loss: 0.9706
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8876 - loss: 0.4672 - val_accuracy: 0.6300 - val_loss: 0.9697
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8930 - loss: 0.4608 - val_accuracy: 0.6250 - val_loss: 0.9687
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8967 - loss: 0.4547 - val_accuracy: 0.6250 - val_loss: 0.9678
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9023 - loss: 0.4487 - val_accuracy: 0.6300 - val_loss: 0.9670
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9061 - loss: 0.4429 - val_accuracy: 0.6300 - val_loss: 0.9663
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9082 - loss: 0.4372 - val_accuracy: 0.6300 - val_loss: 0.9655
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9096 - loss: 0.4317 - val_accuracy: 0.6350 - val_loss: 0.9649
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9096 - loss: 0.4263 - val_accuracy: 0.6350 - val_loss: 0.9643
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9115 - loss: 0.4211 - val_accuracy: 0.6300 - val_loss: 0.9637
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9137 - loss: 0.4160 - val_accuracy: 0.6300 - val_loss: 0.9631
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9170 - loss: 0.4110 - val_accuracy: 0.6300 - val_loss: 0.9626
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.3918 - loss: 1.4808 - val_accuracy: 0.4750 - val_loss: 1.3358
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4873 - loss: 1.2408 - val_accuracy: 0.5150 - val_loss: 1.2119
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5733 - loss: 1.0558 - val_accuracy: 0.5450 - val_loss: 1.1234
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6351 - loss: 0.9148 - val_accuracy: 0.5150 - val_loss: 1.1914
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6972 - loss: 0.8156 - val_accuracy: 0.4900 - val_loss: 1.2679
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7304 - loss: 0.7638 - val_accuracy: 0.5850 - val_loss: 0.9945
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8003 - loss: 0.6062 - val_accuracy: 0.5600 - val_loss: 1.0846
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8553 - loss: 0.5117 - val_accuracy: 0.5500 - val_loss: 1.0438
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8387 - loss: 0.5087 - val_accuracy: 0.5950 - val_loss: 0.9587
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8923 - loss: 0.3861 - val_accuracy: 0.5900 - val_loss: 1.0089
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9427 - loss: 0.3003 - val_accuracy: 0.5600 - val_loss: 1.0384
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9575 - loss: 0.2572 - val_accuracy: 0.6150 - val_loss: 0.9805
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9701 - loss: 0.2040 - val_accuracy: 0.6100 - val_loss: 0.9957
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9803 - loss: 0.1636 - val_accuracy: 0.6000 - val_loss: 1.0021
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9919 - loss: 0.1356 - val_accuracy: 0.6000 - val_loss: 1.0145
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9924 - loss: 0.1139 - val_accuracy: 0.5950 - val_loss: 1.0277
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9943 - loss: 0.0968 - val_accuracy: 0.6000 - val_loss: 1.0406
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9943 - loss: 0.0829 - val_accuracy: 0.6050 - val_loss: 1.0537
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9972 - loss: 0.0715 - val_accuracy: 0.6000 - val_loss: 1.0671
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 0.0622 - val_accuracy: 0.6050 - val_loss: 1.0800
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 0.0545 - val_accuracy: 0.6050 - val_loss: 1.0931
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 0.0481 - val_accuracy: 0.6050 - val_loss: 1.1058
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0427 - val_accuracy: 0.6050 - val_loss: 1.1181
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.0382 - val_accuracy: 0.6050 - val_loss: 1.1297
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 0.6000 - val_loss: 1.1413
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0311 - val_accuracy: 0.6000 - val_loss: 1.1521
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.6000 - val_loss: 1.1625
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.6000 - val_loss: 1.1726
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.6050 - val_loss: 1.1824
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.6100 - val_loss: 1.1916
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.6100 - val_loss: 1.2009
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.6050 - val_loss: 1.2095
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.6000 - val_loss: 1.2181
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.6050 - val_loss: 1.2263
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.6050 - val_loss: 1.2344
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.6000 - val_loss: 1.2421
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.6000 - val_loss: 1.2498
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.6000 - val_loss: 1.2571
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.6000 - val_loss: 1.2643
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.6000 - val_loss: 1.2712
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.6000 - val_loss: 1.2780
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6000 - val_loss: 1.2847
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.6000 - val_loss: 1.2910
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.6000 - val_loss: 1.2974
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.6000 - val_loss: 1.3037
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.5950 - val_loss: 1.3096
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.5950 - val_loss: 1.3154
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.6000 - val_loss: 1.3211
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.6000 - val_loss: 1.3267
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.6000 - val_loss: 1.3320

# %% [markdown]
# Let's try this pipeline for test data!

# %%
# evaluation
train_score = model_SLP.evaluate(train_feats_matrix, train_label_matrix, batch_size=100)
val_score = model_SLP.evaluate(val_feats_matrix, val_label_matrix, batch_size=100)
test_score = model_SLP.evaluate(test_feats_matrix, test_label_matrix, batch_size=100)
print("SLP training loss:", train_score[0], "training accuracy", train_score[1])
print("SLP validating loss:", val_score[0], "validating accuracy", val_score[1])
print("SLP test loss:", test_score[0], "test accuracy", test_score[1])

train_score = model_MLP.evaluate(train_feats_matrix, train_label_matrix, batch_size=100)
val_score = model_MLP.evaluate(val_feats_matrix, val_label_matrix, batch_size=100)
test_score = model_MLP.evaluate(test_feats_matrix, test_label_matrix, batch_size=100)
print("MLP training loss:", train_score[0], "training accuracy", train_score[1])
print("MLP validating loss:", val_score[0], "validating accuracy", val_score[1])
print("MLP test loss:", test_score[0], "test accuracy", test_score[1])
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9342 - loss: 0.3872
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6233 - loss: 0.9833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5200 - loss: 1.1627
# SLP training loss: 0.3928190767765045 training accuracy 0.9305555820465088
# SLP validating loss: 0.9626164436340332 validating accuracy 0.6299999952316284
# SLP test loss: 1.1466771364212036 test accuracy 0.5224999785423279
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0064
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5833 - loss: 1.3669
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5410 - loss: 2.0224
# MLP training loss: 0.006684664636850357 training accuracy 1.0
# MLP validating loss: 1.3319934606552124 validating accuracy 0.6000000238418579
# MLP test loss: 1.9646204710006714 test accuracy 0.5400000214576721

# %% [markdown]
# You can try different hyperparameters by yourselves.

# %% [markdown]
# However, our classifier here is overfitted. The training loss is much smaller than the test loss.
# Later we will introduce more strategies to make classifiers better generalized.

# %%
# save predictions
# test_pred = model.predict_classes(test_feats_matrix)
test_pred = np.argmax(model_MLP.predict(test_feats_matrix), axis=-1)
write_predictions(pred_file, test_pred)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ### Model Regularization

# %% [markdown]
# I have implement the L2 regularizer in the classifier. You can use it by simply setting the *l2_reg* parameter, such as 0.01.

# %%
model_l2 = build_SLP(len(feats_dict), num_classes, learning_rate=0.1, l2_reg=0.01)

history_l2 = model_l2.fit(train_feats_matrix, train_label_matrix,
          validation_data=(val_feats_matrix, val_label_matrix),
          epochs=50, batch_size=100, verbose=0)

train_score = model_l2.evaluate(train_feats_matrix, train_label_matrix, batch_size=100)
val_score = model_l2.evaluate(val_feats_matrix, val_label_matrix, batch_size=100)
test_score = model_l2.evaluate(test_feats_matrix, test_label_matrix, batch_size=100)
print("training loss:", train_score[0], "training accuracy", train_score[1])
print("validating loss:", val_score[0], "validating accuracy", val_score[1])
print("test loss:", test_score[0], "test accuracy", test_score[1])
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8477 - loss: 0.8457
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6100 - loss: 1.2455
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5617 - loss: 1.3478
# training loss: 0.8490008115768433 training accuracy 0.8411111235618591
# validating loss: 1.2266501188278198 validating accuracy 0.6200000047683716
# test loss: 1.3378090858459473 test accuracy 0.5575000047683716

# %% [markdown]
# ## Visualization

# %% [markdown]
# The training performance is much better than test performance.
#
# It is not straghtforward to analyze models. We can see the curves of loss and accuracy briefly.

# %%
import matplotlib.pyplot as plt

for history in [history_SLP, history_MLP]:
    ''' Plot loss-iteration '''
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(history.history["loss"], label="training", color="blue", linestyle="dashed")
    plt.plot(history.history["val_loss"], label="validating", color="orange")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.legend()

    ''' Plot accuracy-iteration '''
    plt.subplot(1,2,2)
    plt.plot(history.history["accuracy"], label="training", color="blue", linestyle="dashed")
    plt.plot(history.history["val_accuracy"], label="validating", color="orange")
    plt.xlabel("Iteration")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.show()

# %% [markdown]
# The training loss curve and accuracy curve look good, while the test curvers are not. And we believe the train loss can be minimized further. On the contrary, test performance will not be improved again.
